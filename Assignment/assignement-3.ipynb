# %% [markdown]
# # Assignment-3

# %% [markdown]
# # Name: Maneel Chauhan

# %%
import numpy as np 
import pandas as pd

# %%
dt = pd.read_csv('Housing.csv')

# %%
dt
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking furnishingstatus
# 0                no             yes        2        furnished
# 1                no             yes        3        furnished
# 2                no              no        2   semi-furnished
# 3                no             yes        3        furnished
# 4                no             yes        2        furnished
# ..              ...             ...      ...              ...
# 540              no              no        2      unfurnished
# 541              no              no        0   semi-furnished
# 542              no              no        0      unfurnished
# 543              no              no        0        furnished
# 544              no              no        0      unfurnished
#
# [545 rows x 12 columns]

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %%
dt.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
dt.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking furnishingstatus
# 540              no              no        2      unfurnished
# 541              no              no        0   semi-furnished
# 542              no              no        0      unfurnished
# 543              no              no        0        furnished
# 544              no              no        0      unfurnished

# %%
dt.shape
# Out:
# (545, 12)

# %% [markdown]
# # Descriptive Analysis

# %%
dt.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
dt.columns.values
# Out:
# array(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'furnishingstatus'], dtype=object)

# %%
dt['mainroad'].value_counts()
# Out:
# yes    468
# no      77
# Name: mainroad, dtype: int64

# %%
dt['guestroom'].value_counts()
# Out:
# no     448
# yes     97
# Name: guestroom, dtype: int64

# %%
dt['hotwaterheating'].value_counts()
# Out:
# no     520
# yes     25
# Name: hotwaterheating, dtype: int64

# %%
dt['airconditioning'].value_counts()
# Out:
# no     373
# yes    172
# Name: airconditioning, dtype: int64

# %% [markdown]
# # The hotwaterheating column has very less number of "yes" values  hence we would drop this column from our data as it is an imbalance data

# %%
dt.drop(columns=['hotwaterheating'],inplace=True)

# %%
#After dropping the column hotwaterheating
dt
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     airconditioning  parking furnishingstatus
# 0               yes        2        furnished
# 1               yes        3        furnished
# 2                no        2   semi-furnished
# 3               yes        3        furnished
# 4               yes        2        furnished
# ..              ...      ...              ...
# 540              no        2      unfurnished
# 541              no        0   semi-furnished
# 542              no        0      unfurnished
# 543              no        0        furnished
# 544              no        0      unfurnished
#
# [545 rows x 11 columns]

# %% [markdown]
# # Import library seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Visualizations

# %%
sns.histplot(x=dt['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(x=dt['area'])
# Out:
# <AxesSubplot:xlabel='area', ylabel='Count'>

# %%
sns.countplot(x=dt['bedrooms'])
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
sns.countplot(x=dt['bathrooms'])
# Out:
# <Axes: xlabel='bathrooms', ylabel='count'>

# %%
sns.countplot(x=dt['stories'])
# Out:
# <Axes: xlabel='stories', ylabel='count'>

# %%
sns.countplot(x=dt['mainroad'])
# Out:
# <Axes: xlabel='mainroad', ylabel='count'>

# %%
sns.countplot(x=dt['guestroom'])
# Out:
# <Axes: xlabel='guestroom', ylabel='count'>

# %%
sns.countplot(x=dt['basement'])
# Out:
# <Axes: xlabel='basement', ylabel='count'>

# %%
sns.countplot(x=dt['airconditioning'])
# Out:
# <Axes: xlabel='airconditioning', ylabel='count'>

# %%
sns.countplot(x=dt['parking'])
# Out:
# <Axes: xlabel='parking', ylabel='count'>

# %%
sns.countplot(x=dt['furnishingstatus'])
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
sns.distplot(x=dt['price'])
# Out:
# C:\Users\Maneel Chauhan\AppData\Local\Temp\ipykernel_25908\2499870194.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=dt['price'])
# <Axes: ylabel='Density'>

# %%
print(dt['price'].skew())
print(dt['price'].kurt())
# Out:
# 1.2122388370279802
# 1.9601302314151994

# %%
sns.distplot(x=dt['area'])
# Out:
# C:\Users\Maneel Chauhan\AppData\Local\Temp\ipykernel_25908\3234293364.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=dt['area'])
# <Axes: ylabel='Density'>

# %%
print(dt['area'].skew())
print(dt['area'].kurt())
# Out:
# 1.321188343153483
# 2.7514801872608086

# %%
sns.boxplot(x=dt['price'])
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(x=dt['area'])
# Out:
# <Axes: xlabel='area'>

# %%
sns.pairplot(dt)

# %%
sns.heatmap(dt.corr())
# Out:
# C:\Users\Maneel Chauhan\AppData\Local\Temp\ipykernel_25908\3293140563.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dt.corr())
# <Axes: >

# %%
dt
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     airconditioning  parking furnishingstatus
# 0               yes        2        furnished
# 1               yes        3        furnished
# 2                no        2   semi-furnished
# 3               yes        3        furnished
# 4               yes        2        furnished
# ..              ...      ...              ...
# 540              no        2      unfurnished
# 541              no        0   semi-furnished
# 542              no        0      unfurnished
# 543              no        0        furnished
# 544              no        0      unfurnished
#
# [545 rows x 11 columns]

# %%
q1 = np.percentile(dt['price'],25)
q3 = np.percentile(dt['price'],75)

lowOutlier =  q1 - 1.5*(q3-q1)
highOutlier =  q3 + 1.5*(q3-q1)

dt = dt[(dt['price']>lowOutlier) & (df['price']<highOutlier)]

# %%
dt.shape
# Out:
# (530, 11)

# %%
q1 = np.percentile(dt['area'],25)
q3 = np.percentile(dt['area'],75)

lowOutlier =  q1 - 1.5*(q3-q1)
highOutlier=  q3 + 1.5*(q3-q1)

dt = dt[(dt['area']>lowOutlier) & (df['area']<highOutlier)]
# Out:
# C:\Users\Maneel Chauhan\AppData\Local\Temp\ipykernel_25908\2778417966.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dt = dt[(dt['area']>lowOutlier) & (df['area']<highOutlier)]

# %%
dt.shape
# Out:
# (517, 11)

# %% [markdown]
# # Categorical columns to numerical columns using hot encoding

# %%
# mainroad , guestroom , basement , airconditioning ,furnishingstatus are these columns to be transformed
dt = pd.get_dummies(data=dt , columns=['mainroad','guestroom' ,'basement','airconditioning','furnishingstatus'],drop_first=True)

# %%
dt
# Out:
#        price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 15   9100000  6000         4          1        2        2             1
# 16   9100000  6600         4          2        2        1             1
# 17   8960000  8500         3          2        4        2             1
# 18   8890000  4600         3          2        2        2             1
# 19   8855000  6420         3          2        2        1             1
# ..       ...   ...       ...        ...      ...      ...           ...
# 540  1820000  3000         2          1        1        2             1
# 541  1767150  2400         3          1        1        0             0
# 542  1750000  3620         2          1        1        0             1
# 543  1750000  2910         3          1        1        0             0
# 544  1750000  3850         3          1        2        0             1
#
#      guestroom_yes  basement_yes  airconditioning_yes  \
# 15               0             1                    0
# 16               1             1                    1
# 17               0             0                    1
# 18               1             0                    1
# 19               0             0                    1
# ..             ...           ...                  ...
# 540              0             1                    0
# 541              0             0                    0
# 542              0             0                    0
# 543              0             0                    0
# 544              0             0                    0
#
#      furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 15                                 1                             0
# 16                                 0                             1
# 17                                 0                             0
# 18                                 0                             0
# 19                                 1                             0
# ..                               ...                           ...
# 540                                0                             1
# 541                                1                             0
# 542                                0                             1
# 543                                0                             0
# 544                                0                             1
#
# [517 rows x 12 columns]

# %%
dt.shape
# Out:
# (517, 12)

# %%
sns.heatmap(dt.corr() , cmap = 'summer')
# Out:
# <Axes: >

# %%
dt['price_per_sqft'] = (dt['price']/dt['area']).astype('int64')

# %%
dt
# Out:
#        price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 15   9100000  6000         4          1        2        2             1
# 16   9100000  6600         4          2        2        1             1
# 17   8960000  8500         3          2        4        2             1
# 18   8890000  4600         3          2        2        2             1
# 19   8855000  6420         3          2        2        1             1
# ..       ...   ...       ...        ...      ...      ...           ...
# 540  1820000  3000         2          1        1        2             1
# 541  1767150  2400         3          1        1        0             0
# 542  1750000  3620         2          1        1        0             1
# 543  1750000  2910         3          1        1        0             0
# 544  1750000  3850         3          1        2        0             1
#
#      guestroom_yes  basement_yes  airconditioning_yes  \
# 15               0             1                    0
# 16               1             1                    1
# 17               0             0                    1
# 18               1             0                    1
# 19               0             0                    1
# ..             ...           ...                  ...
# 540              0             1                    0
# 541              0             0                    0
# 542              0             0                    0
# 543              0             0                    0
# 544              0             0                    0
#
#      furnishingstatus_semi-furnished  furnishingstatus_unfurnished  \
# 15                                 1                             0
# 16                                 0                             1
# 17                                 0                             0
# 18                                 0                             0
# 19                                 1                             0
# ..                               ...                           ...
# 540                                0                             1
# 541                                1                             0
# 542                                0                             1
# 543                                0                             0
# 544                                0                             1
#
#      price_per_sqft
# 15             1516
# 16             1378
# 17             1054
# 18             1932
# 19             1379
# ..              ...
# 540             606
# 541             736
# 542             483
# 543             601
# 544             454
#
# [517 rows x 13 columns]

# %%
sns.boxplot(x=dt['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
dt = dt[(dt['price_per_sqft'])<=1700]

# %%
dt.shape
# Out:
# (496, 13)

# %%
sns.boxplot(x=dt['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
sns.boxplot(x=dt['price'])
# Out:
# <Axes: xlabel='price'>

# %%
dt = dt[(dt['price'])<=8e6]

# %%
dt.shape
# Out:
# (477, 13)

# %%
sns.boxplot(x=dt['price'])
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(x=dt['area'])
# Out:
# <Axes: xlabel='area'>

# %%
dt = dt[(dt['area'])<=9300]

# %%
dt.shape
# Out:
# (469, 13)

# %%
sns.boxplot(x=dt['area'])
# Out:
# <Axes: xlabel='area'>

# %% [markdown]
# # Import library sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder , StandardScaler

# %%
X = dt.drop(columns=['price'])
y= dt['price']

# %%
X
# Out:
#      area  bedrooms  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 37   9000         4          2        4        2             1              0
# 38   6000         3          1        4        2             1              1
# 39   6000         4          2        4        1             1              0
# 40   6550         3          1        2        0             1              0
# 41   6360         3          2        4        0             1              0
# ..    ...       ...        ...      ...      ...           ...            ...
# 540  3000         2          1        1        2             1              0
# 541  2400         3          1        1        0             0              0
# 542  3620         2          1        1        0             1              0
# 543  2910         3          1        1        0             0              0
# 544  3850         3          1        2        0             1              0
#
#      basement_yes  airconditioning_yes  furnishingstatus_semi-furnished  \
# 37              0                    1                                0
# 38              0                    1                                0
# 39              0                    1                                1
# 40              1                    1                                0
# 41              0                    1                                0
# ..            ...                  ...                              ...
# 540             1                    0                                0
# 541             0                    0                                1
# 542             0                    0                                0
# 543             0                    0                                0
# 544             0                    0                                0
#
#      furnishingstatus_unfurnished  price_per_sqft
# 37                              0             886
# 38                              1            1327
# 39                              0            1318
# 40                              0            1202
# 41                              0            1232
# ..                            ...             ...
# 540                             1             606
# 541                             0             736
# 542                             1             483
# 543                             0             601
# 544                             1             454
#
# [469 rows x 12 columns]

# %%
y
# Out:
# 37     7980000
# 38     7962500
# 39     7910000
# 40     7875000
# 41     7840000
#         ...
# 540    1820000
# 541    1767150
# 542    1750000
# 543    1750000
# 544    1750000
# Name: price, Length: 469, dtype: int64

# %%
X_train ,X_test , y_train , y_test = train_test_split(X,y,test_size=0.2 ,  random_state= 0 )

# %%
X_train.shape
# Out:
# (375, 12)

# %%
X_test.shape
# Out:
# (94, 12)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
scaler = StandardScaler()

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(scaler,lr)

# %%
pipe.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_lr = pipe.predict(X_test)

# %%
r2_score(y_test , y_pred_lr)
# Out:
# 0.8977025782218491

# %%
lasso = Lasso()

# %%
pipe = make_pipeline(scaler,lasso)

# %%
pipe.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso = pipe.predict(X_test)

# %%
r2_score(y_test , y_pred_lasso)
# Out:
# 0.8977029793008444

# %%
ridge = Ridge()

# %%
pipe = make_pipeline(scaler , ridge)

# %%
pipe.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge = pipe.predict(X_test)

# %%
r2_score(y_test , y_pred_ridge)
# Out:
# 0.8983551363072464

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# #  Assuming you have your ground truth labels in y_test and your predicted labels in y_pred_lasso

# %%
# Mean Squared Error (MSE)
MSE = mean_squared_error(y_test, y_pred_lasso)
print("Mean Squared Error:", MSE)

# Mean Absolute Error (MAE)
MSE = mean_absolute_error(y_test, y_pred_lasso)
print("Mean Absolute Error:", MSE)

# R-squared score
r2 = r2_score(y_test, y_pred_lasso)
print("R-squared Score:", r2)
# Out:
# Mean Squared Error: 186170700920.49783
# Mean Absolute Error: 300067.6286655653
# R-squared Score: 0.8977029793008444

# %%
MSE = mean_squared_error(y_test, y_pred_lr)
print("Mean Squared Error:", MSE)

# Mean Absolute Error (MAE)
MSE = mean_absolute_error(y_test, y_pred_lr)
print("Mean Absolute Error:", MSE)

# R-squared score
r2 = r2_score(y_test, y_pred_lr)
print("R-squared Score:", r2)
# Out:
# Mean Squared Error: 186171430845.54538
# Mean Absolute Error: 300068.30647191795
# R-squared Score: 0.8977025782218491
